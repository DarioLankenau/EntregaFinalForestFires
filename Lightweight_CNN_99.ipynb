# %% [markdown]
# # Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # Load modules

# %%
import os
import cv2
import imghdr
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# # Load and clean image data

# %%
base_dir = "/content/drive/Shared drives/Los Errescuer/Lightweight CNN/"
data_dir = os.path.join(base_dir, "wildfire_dataset")
classes = os.listdir(data_dir)
print(classes)
# Out:
# ['forest', 'fire', 'smoke']

# %% [markdown]
# ## Clean data

# %%
# # Clean Data
# image_exts = ["jpg", "png", "jpeg", "bmp"]

# for image_class in os.listdir(data_dir):
#   for image in os.listdir(os.path.join(data_dir, image_class)):
#     image_path = os.path.join(data_dir, image_class, image)
#     try:
#       img = cv2.imread(image_path)
#       tip = imghdr.what(image_path)
#       if tip not in image_exts:
#         print(f"Incorrect extension for image: {image_path}")
#         os.remove(image_path)
#     except Exception as e:
#       print(f"Issue with image {image_path}")

# %% [markdown]
# ## Load data as Tensorflow pipeline

# %%
data = tf.keras.utils.image_dataset_from_directory(data_dir, class_names=classes, 
                                                   batch_size=16, image_size=(128,128),
                                                   shuffle=True, seed=0)
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
# Batch of images
batch[0].shape
# Out:
# Found 781 files belonging to 3 classes.
# (16, 128, 128, 3)

# %%
# Display example images and labels
n = 5
fig, axes = plt.subplots(ncols=n, figsize=(15,8))
for idx, img in enumerate(batch[0][:n]):
  axes[idx].imshow(img.astype(int))
  axes[idx].set_title(batch[1][idx])

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# ## Scaling

# %%
data = data.map(lambda x,y: (x/255, y))
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()

# %%
width = batch[0].shape[1]
height = batch[0].shape[2]
channels = batch[0].shape[3]

# %% [markdown]
# # Train-Validate Split

# %%
train_size = int(len(data)*0.7)
validate_size = int(len(data)*0.2)
test_size = int(len(data)*0.1)

train = data.take(train_size)
val = data.skip(train_size).take(validate_size)
test = data.skip(train_size+validate_size).take(test_size)

# %%
# Class distribution
for batch in train.as_numpy_iterator():
  x,y = batch
  print(np.unique(y, return_counts=True)[1])

# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ## Build the network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, RandomZoom, RandomRotation, RandomFlip, RandomBrightness

# %%
data_augment = Sequential()

data_augment.add(RandomZoom(0.1, input_shape=(width, height, channels)))
data_augment.add(RandomFlip("horizontal"))
# data_augment.add(RandomRotation(np.pi/6))
# data_augment.add(RandomBrightness(0.1))

# %%
model = Sequential()

# %%
model.add(data_augment)
model.add(Conv2D(16, (3,3), activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512, activation='relu')) # kernel_regularizer='l2'
model.add(Dense(len(classes), activation='softmax'))

# %%
adam = tf.optimizers.Adam()
cce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
bce = tf.keras.losses.BinaryCrossentropy()

model.compile(optimizer=adam, loss = cce, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 6,448,163
# Trainable params: 6,448,163
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
logdir = os.path.join(base_dir, "logs")
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(monitor='val_accuracy', save_best_only=True)

# %%
epochs = 40
history = model.fit(train, epochs = epochs, validation_data=val, callbacks = [model_checkpoint])
# Out:
# Epoch 1/40
# 34/34 [==============================] - 28s 753ms/step - loss: 0.5604 - accuracy: 0.7776 - val_loss: 0.3316 - val_accuracy: 0.8750
# Epoch 2/40
# 34/34 [==============================] - 26s 743ms/step - loss: 0.3174 - accuracy: 0.8989 - val_loss: 0.4660 - val_accuracy: 0.8611
# Epoch 3/40
# 34/34 [==============================] - 30s 856ms/step - loss: 0.2913 - accuracy: 0.9062 - val_loss: 0.2033 - val_accuracy: 0.9306
# Epoch 4/40
# 34/34 [==============================] - 27s 752ms/step - loss: 0.3269 - accuracy: 0.8952 - val_loss: 0.3800 - val_accuracy: 0.8889
# Epoch 5/40
# 34/34 [==============================] - 27s 741ms/step - loss: 0.3427 - accuracy: 0.8529 - val_loss: 0.3410 - val_accuracy: 0.8681
# Epoch 6/40
# 34/34 [==============================] - 27s 746ms/step - loss: 0.2700 - accuracy: 0.9154 - val_loss: 0.1579 - val_accuracy: 0.9653
# Epoch 7/40
# 34/34 [==============================] - 26s 741ms/step - loss: 0.2409 - accuracy: 0.9099 - val_loss: 0.2050 - val_accuracy: 0.9306
# Epoch 8/40
# 34/34 [==============================] - 24s 666ms/step - loss: 0.2281 - accuracy: 0.9154 - val_loss: 0.1963 - val_accuracy: 0.9097
# Epoch 9/40
# 34/34 [==============================] - 27s 742ms/step - loss: 0.1833 - accuracy: 0.9320 - val_loss: 0.3163 - val_accuracy: 0.9028
# Epoch 10/40
# 34/34 [==============================] - 26s 738ms/step - loss: 0.1459 - accuracy: 0.9504 - val_loss: 0.1619 - val_accuracy: 0.9444
# Epoch 11/40
# 34/34 [==============================] - 240s 7s/step - loss: 0.1298 - accuracy: 0.9522 - val_loss: 0.1333 - val_accuracy: 0.9444
# Epoch 12/40
# 34/34 [==============================] - 26s 735ms/step - loss: 0.1334 - accuracy: 0.9540 - val_loss: 0.1185 - val_accuracy: 0.9722
# Epoch 13/40
# 34/34 [==============================] - 26s 734ms/step - loss: 0.1067 - accuracy: 0.9651 - val_loss: 0.3320 - val_accuracy: 0.9097
# Epoch 14/40
# 34/34 [==============================] - 26s 734ms/step - loss: 0.1954 - accuracy: 0.9467 - val_loss: 0.1048 - val_accuracy: 0.9653
# Epoch 15/40
# 34/34 [==============================] - 33s 945ms/step - loss: 0.1319 - accuracy: 0.9614 - val_loss: 0.1232 - val_accuracy: 0.9514
# Epoch 16/40
# 34/34 [==============================] - 28s 780ms/step - loss: 0.0969 - accuracy: 0.9651 - val_loss: 0.1375 - val_accuracy: 0.9583
# Epoch 17/40
# 34/34 [==============================] - 31s 842ms/step - loss: 0.0838 - accuracy: 0.9632 - val_loss: 0.0730 - val_accuracy: 0.9722
# Epoch 18/40
# 34/34 [==============================] - 26s 734ms/step - loss: 0.0883 - accuracy: 0.9706 - val_loss: 0.1133 - val_accuracy: 0.9653
# Epoch 19/40
# 34/34 [==============================] - 24s 678ms/step - loss: 0.0540 - accuracy: 0.9816 - val_loss: 0.1433 - val_accuracy: 0.9583
# Epoch 20/40
# 34/34 [==============================] - 26s 737ms/step - loss: 0.0739 - accuracy: 0.9724 - val_loss: 0.0607 - val_accuracy: 0.9722
# Epoch 21/40
# 34/34 [==============================] - 26s 729ms/step - loss: 0.0804 - accuracy: 0.9779 - val_loss: 0.0751 - val_accuracy: 0.9583
# Epoch 22/40
# 34/34 [==============================] - 26s 740ms/step - loss: 0.0681 - accuracy: 0.9779 - val_loss: 0.1338 - val_accuracy: 0.9722
# Epoch 23/40
# 34/34 [==============================] - 26s 731ms/step - loss: 0.0187 - accuracy: 0.9982 - val_loss: 0.0961 - val_accuracy: 0.9792
# Epoch 24/40
# 34/34 [==============================] - 26s 736ms/step - loss: 0.0155 - accuracy: 0.9963 - val_loss: 0.0949 - val_accuracy: 0.9792
# Epoch 25/40
# 34/34 [==============================] - 24s 660ms/step - loss: 0.0498 - accuracy: 0.9835 - val_loss: 0.2546 - val_accuracy: 0.9583
# Epoch 26/40
# 34/34 [==============================] - 24s 662ms/step - loss: 0.1624 - accuracy: 0.9467 - val_loss: 0.1203 - val_accuracy: 0.9514
# Epoch 27/40
# 34/34 [==============================] - 38s 1s/step - loss: 0.0805 - accuracy: 0.9761 - val_loss: 0.0701 - val_accuracy: 0.9792
# Epoch 28/40
# 34/34 [==============================] - 26s 734ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 0.0807 - val_accuracy: 0.9792
# Epoch 29/40
# 34/34 [==============================] - 26s 730ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.2028 - val_accuracy: 0.9514
# Epoch 30/40
# 34/34 [==============================] - 24s 662ms/step - loss: 0.0455 - accuracy: 0.9871 - val_loss: 0.2090 - val_accuracy: 0.9514
# Epoch 31/40
# 34/34 [==============================] - 28s 798ms/step - loss: 0.0119 - accuracy: 0.9945 - val_loss: 0.0870 - val_accuracy: 0.9722
# Epoch 32/40
# 34/34 [==============================] - 26s 733ms/step - loss: 0.0777 - accuracy: 0.9743 - val_loss: 0.2750 - val_accuracy: 0.9375
# Epoch 33/40
# 34/34 [==============================] - 26s 728ms/step - loss: 0.0681 - accuracy: 0.9835 - val_loss: 0.1105 - val_accuracy: 0.9722
# Epoch 34/40
# 34/34 [==============================] - 24s 660ms/step - loss: 0.0935 - accuracy: 0.9724 - val_loss: 0.1987 - val_accuracy: 0.9514
# Epoch 35/40
# 34/34 [==============================] - 26s 728ms/step - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.0659 - val_accuracy: 0.9722
# Epoch 36/40
# 34/34 [==============================] - 28s 797ms/step - loss: 0.0350 - accuracy: 0.9871 - val_loss: 0.1874 - val_accuracy: 0.9514
# Epoch 37/40
# 34/34 [==============================] - 27s 746ms/step - loss: 0.0338 - accuracy: 0.9853 - val_loss: 0.0992 - val_accuracy: 0.9861
# Epoch 38/40
# 34/34 [==============================] - 24s 665ms/step - loss: 0.0097 - accuracy: 0.9982 - val_loss: 0.1702 - val_accuracy: 0.9722
# Epoch 39/40
# 34/34 [==============================] - 24s 657ms/step - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.1888 - val_accuracy: 0.9722
# Epoch 40/40
# 34/34 [==============================] - 26s 729ms/step - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.0256 - val_accuracy: 0.9931

# %% [markdown]
# ## Model Performance

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 14
plt.rcParams["text.usetex"] = True
plt.rcParams["axes.titlesize"] = 16

fig, axes = plt.subplots(1,2, figsize=(12,4))

axes[0].plot(history.history["loss"], color="royalblue", label="Train Loss", marker="o", linestyle="--")
axes[0].plot(history.history["val_loss"], color="darkorange", label="Validation Loss", marker="^")
axes[0].set_title("Loss Function", fontsize=18)
axes[0].grid()
axes[0].legend()

axes[1].plot(history.history["accuracy"], color="royalblue", label="Train Accuracy", marker="o", linestyle="--")
axes[1].plot(history.history["val_accuracy"], color="darkorange", label="Validation Accuracy", marker="^")
axes[1].set_title("Accuracy Evolution")
axes[1].grid()
axes[1].legend()
plt.show()
